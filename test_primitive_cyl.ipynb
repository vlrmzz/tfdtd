# %%
from src.utilis import *
import matplotlib.pyplot as plt
import numpy as np

# %%
# Parameters
size_x = 300
size_y = 300
center_x = 150
center_y = 150
radius = 10
epsr = 30
epsz = 8.854e-12
sigma =  0.3
gaz = torch.ones((size_x, size_y), dtype=torch.float64)
gbz = torch.ones((size_x, size_y), dtype=torch.float64)
dt = 0.01/6e8

# %% [markdown]
# ### Testing generate circle

# %%
gaz,gbz = circle_primitive(size_x,size_y,center_x,center_y,radius,epsr,epsz,sigma,gaz,gbz,dt)
# Out:
# c:\Users\mazzo\anaconda3\envs\fdtd\lib\site-packages\torch\functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at C:\cb\pytorch_1000000000000\work\aten\src\ATen\native\TensorShape.cpp:3484.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# Visualize permittivity distribution
plt.imshow(gaz, cmap='jet')
plt.title('Distribution')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(cmap='jet')
plt.show()

# %%
# Visualize permittivity distribution
plt.imshow(gbz, cmap='jet')
plt.title('Distribution')
plt.xlabel('x')
plt.ylabel('y')
plt.colorbar(cmap='jet')
plt.show()
