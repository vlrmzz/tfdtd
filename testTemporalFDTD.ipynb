# %% [markdown]
# Import simulator and utilities

# %%
from Tfdtd.base import TFDTD2D
from Tfdtd.detectors import PointDetector
from Tfdtd.sources import PointSource, LineSource

from Tfdtd.utilities import print_setup_info
from Tfdtd.viz import viz2D

# %% [markdown]
# ### Setting the simulation parameters from a dictionary

# %% [markdown]
# #### TM

# %%
params = {
    'backend': 'pytorch',
    'precision': 'float64',
    'nx': 200,
    'ny': 200,
    'time_steps': 150,
    'dx': 0.01,
    'dy': 0.01,
    'polarization': 'TM',
    'use_pml': True,
    'pml_thickness': 20,
    'use_tfsf': False,
    'tfsf_thickness': 10,
}

# %% [markdown]
# #### TE

# %%
params = {
    'backend': 'pytorch',
    'precision': 'float64',
    'nx': 200,
    'ny': 200,
    'time_steps': 250,
    'dx': 0.01,
    'dy': 0.01,
    'polarization': 'TE',
    'use_pml': True,
    'pml_thickness': 20,
    'use_tfsf': False,
    'tfsf_thickness': 10,
}

# %% [markdown]
# ### Testing initializations

# %%
sim = TFDTD2D(params = params) # to read configuration from python dictionary
# Out:
# Reading configuration from dictionary...

# %% [markdown]
# #### Change the background at half the number of time step

# %%
for t in range(75,151):
    sim.eps_r[50:,:,t] = 12
sim.calculate_e_field_coefficients()

# %% [markdown]
# ### Set detectors

# %%
detector_params = {
    'name': 'detector1',
    'position': (50, 50),
}
point_detector = PointDetector(detector_params)
sim.add_detector(point_detector)

# %% [markdown]
# ### Set sources

# %% [markdown]
# #### Point source

# %%
source_params ={
    'source_type': 'point_source',
    'function': 'sinusoidal',
    'frequency': 1500e6,
    'source_x': 30,
    'source_y': 30
}
source_params ={
    'source_type': 'point_source',
    'function': 'gaussian_pulse',
    'frequency': 1500e6,
    'source_x': 30,
    'source_y': 30
}
point_source = PointSource(source_params)
sim.add_source(point_source)

# %% [markdown]
# #### Line source

# %%
source_params ={
    'function': 'sinusoidal',
    'frequency': 1500e6,
    'source_type': 'line_source',
    'x': 20,
    'y1': 40,
    'y2': 60
}
line_source = LineSource(source_params)
sim.add_source(line_source)

# %% [markdown]
# ### Print simulation info

# %%
print_setup_info(sim)
# Out:
# Simulation setup information:
# nx: 200
# ny: 200
# time_steps: 150
# dx: 0.01
# dy: 0.01
# dt: 2.358654336749684e-11
# use_pml: True
# pml_thickness: 20
# c: 299792458
# epsilon_0: 8.85418782e-12
# mu_0: 1.25663706e-06
# Source 0: source_type: point_source, function: sinusoidal, source_x: 30, source_y: 30, frequency: 1500000000.0, omega: 9424777960.769379
# Detector 0: Detector: detector1, Position: (50, 50)

# %% [markdown]
# ### Show material distribution

# %% [markdown]
# ### Test simulation

# %%
import numpy as np
import os

def save_field_component(field_component, field_name, time_step, output_dir="output"):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    file_name = f"{field_name}_{time_step}.npy"
    file_path = os.path.join(output_dir, file_name)
    np.save(file_path, field_component)

# %%
for i in range(1, sim.time_steps):
        sim.simulation_step(i)
        sim.record_detectors(sim.e_field[:,:,2])
        #save_field_component(sim.e_field, 'e_field', i)
        sim.time += sim.dt

# %%
import matplotlib.pyplot as plt
import numpy as np

def viz2D(sim,field):


    # plot the Ez field with cmap jet
    fig, ax = plt.subplots(figsize=(8, 6))
    im = ax.imshow(np.transpose(field), cmap='Blues', extent=[0, sim.nx*sim.dx*1e6, sim.ny*sim.dy*1e6, 0])
    ax.set_xlabel('x (um)')
    ax.set_ylabel('y (um)')
    ax.set_title('Field')

    fig.colorbar(im)
    plt.show()

# %%
viz2D(sim,sim.e_field[:,:,2])

# %%
import matplotlib.pyplot as plt

def binary_to_image(binary_file, output_dir="output"):
    field_component = np.load(binary_file)
    normalized_field_component = (field_component - field_component.min()) / (field_component.max() - field_component.min()) * 2 - 1
    plt.imshow(normalized_field_component, cmap='viridis', vmin=-1, vmax=1)
    plt.colorbar()
    plt.title(os.path.splitext(os.path.basename(binary_file))[0])
    image_file = os.path.splitext(os.path.basename(binary_file))[0] + ".png"
    plt.savefig(os.path.join(output_dir, image_file))
    plt.close()

for file_name in os.listdir("output"):
    if file_name.endswith(".npy"):
        binary_to_image(os.path.join("output", file_name))
# Out:
# C:\Users\mazzo\AppData\Local\Temp\ipykernel_14788\532506282.py:5: RuntimeWarning: invalid value encountered in true_divide
#   normalized_field_component = (field_component - field_component.min()) / (field_component.max() - field_component.min()) * 2 - 1

# %%
# !pip install imageio
# !pip install imageio[ffmpeg]
# Out:
# Requirement already satisfied: imageio in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (2.28.0)
# Requirement already satisfied: numpy in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (from imageio) (1.22.3)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (from imageio) (9.4.0)
# Requirement already satisfied: imageio[ffmpeg] in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (2.28.0)
# Requirement already satisfied: numpy in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (from imageio[ffmpeg]) (1.22.3)
# Requirement already satisfied: pillow>=8.3.2 in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (from imageio[ffmpeg]) (9.4.0)
# Collecting imageio-ffmpeg
#   Downloading imageio_ffmpeg-0.4.8-py3-none-win_amd64.whl (22.6 MB)
#      ---------------------------------------- 22.6/22.6 MB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: psutil in c:\users\mazzo\anaconda3\envs\fdtd\lib\site-packages (from imageio[ffmpeg]) (5.9.0)
# Installing collected packages: imageio-ffmpeg
# Successfully installed imageio-ffmpeg-0.4.8

# %%
import imageio
import re

def create_video_from_images(image_files, output_file, fps=5):
    with imageio.get_writer(output_file, mode='I', fps=fps) as writer:
        for image_file in image_files:
            image = imageio.imread(image_file)
            writer.append_data(image)

def natural_sort_key(s):
    return [int(t) if t.isdigit() else t for t in re.split(r"(\d+)", s)]

image_files = [os.path.join("output", file_name) for file_name in os.listdir("output") if file_name.endswith(".png")]
image_files.sort(key=natural_sort_key)

create_video_from_images(image_files, "simulation_video.mp4")
# Out:
# C:\Users\mazzo\AppData\Local\Temp\ipykernel_14788\3306437442.py:7: DeprecationWarning: Starting with ImageIO v3 the behavior of this function will switch to that of iio.v3.imread. To keep the current behavior (and make this warning disappear) use `import imageio.v2 as imageio` or call `imageio.v2.imread` directly.
#   image = imageio.imread(image_file)

# %%
from matplotlib import pyplot as plt
plt.plot(point_detector.recorded_values)
